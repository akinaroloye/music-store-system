# %%
# !python --version
# Out:
# Python 3.12.7

# %%
import subscriptionManager as subm
import feedbackManager as feedm

subscriptions = subm.load_subscriptions()
feedback_list = feedm.load_feedback()

print(subscriptions)
def checkSubscribed():
    #Use this to check if the user is subscribed
    subm.check_subscription() #"User", subscriptions in bracket
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 import subscriptionManager as subm
#       2 import feedbackManager as feedm
# ----> 4 subscriptions = subm.load_subscriptions()
#       5 feedback_list = feedm.load_feedback()
#       7 print(subscriptions)
#
# File c:\Users\Gary\OneDrive - Loughborough University\work\support\python\24COA122\subscriptionManager.py:37, in load_subscriptions(file_name)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Subscription_Info.txt'

# %%
import subscriptionManager as subm
import feedbackManager as feedm

subscriptions = subm.load_subscriptions()
feedback_list = feedm.load_feedback()

#print(subscriptions)
def checkSubscribed():
    #Use this to check if the user is subscribed
    userID = ""
    while len(userID) != 4:
        userID = input("What is your unique customer ID: ")
        if len(userID) != 4:
            print("Your userID can only be 4 characters long. Try again!")
    subm.check_subscription(userID, subscriptions) #"User", subscriptions in bracket
checkSubscribed()
# Out:
# {'abcd': {'SubscriptionType': 'Basic', 'StartDate': datetime.datetime(2021, 11, 15, 0, 0), 'EndDate': datetime.datetime(2025, 11, 30, 0, 0)}, 'lbro': {'SubscriptionType': 'Premium', 'StartDate': datetime.datetime(2022, 7, 9, 0, 0), 'EndDate': datetime.datetime(2025, 12, 24, 0, 0)}}
# What is your unique customer ID:  vuhvdi
# Your userID can only be 4 characters long. Try again!
# What is your unique customer ID:  helloworld
# Your userID can only be 4 characters long. Try again!
# What is your unique customer ID:  54
# Your userID can only be 4 characters long. Try again!
# What is your unique customer ID:  coab

# %%
import subscriptionManager as subm
import feedbackManager as feedm

subscriptions = subm.load_subscriptions()
feedback_list = feedm.load_feedback()

#print(subscriptions)
def checkSubscribed():
    #Use this to check if the user is subscribed
    userID = ""
    while len(userID) != 4:
        userID = input("What is your unique customer ID: ")
        if len(userID) != 4:
            print("Your userID can only be 4 characters long. Try again!")
    subm.check_subscription(userID, subscriptions) #"User", subscriptions in bracket
checkSubscribed()
